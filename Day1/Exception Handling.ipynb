# %% [markdown]
# # Handling an Exception

# %%
#To handle an in python try except clause is used
#example

# %%
inp=int(input("Enter a Number")) #input  a string value
print(inp)
# Out:
# Enter a Numberbvh
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-3c4adb2b1e50> in <module>()
# ----> 1 inp=int(input("Enter a Number")) #input  a string value
#       2 print(inp)
#
# ValueError: invalid literal for int() with base 10: 'bvh'

# %%
try:
    inp=int(input("Enter a Number"))
except Exception as e:
    print(e)
# Out:
# Enter a Numberdd3e2
# invalid literal for int() with base 10: 'dd3e2'

# %% [markdown]
# # Built In Exceptions

# %%
# link to built in exceptions
https://docs.python.org/2/library/exceptions.html

# %% [markdown]
# # Raising an Exception

# %%
#Raise an exception
#Some times one needs to raise an exception by itself

# %%
#Example 
#Keyword raise is used to an exception
try:
    inp=int(input("Enter a Number"))
    if(inp<10):
        raise Exception("Value less than zero")
except Exception as e:
    print(e)
# Out:
# Enter a Number-5
# Value less than zero
